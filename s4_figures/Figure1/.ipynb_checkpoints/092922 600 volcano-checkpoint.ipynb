# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pipe_util2
import os

# %% [markdown]
# # master sheet processing

# %%
# master sheet
master_file = "Master_spreadsheet_2.csv"
master = pd.read_csv(master_file, header=0)
master.head(3)
# Out:
#                UniqueID Symbol     150.III      150.II      150.I  \
# 0     TC1100006831.hg.1    ADM  126.399571  166.725941  78.725779
# 1  HTA2-neg-47424102_st    NaN   14.431287    6.693803  40.556178
# 2  HTA2-neg-47419722_st    NaN   74.756089   38.967597  17.221799
#
#      600D1.III     600D1.II      600D1.I     600D6.III     600D6.II  ...  \
# 0  1118.446273  1017.212962  2722.072996  10110.314320  1827.796602  ...
# 1     5.657442     4.989378    79.944620    720.413072   129.054704  ...
# 2   312.250910   158.786144   248.611114   1216.390046  1387.411440  ...
#
#    P-value (600D1 vs 600D6)   FDR.4  600D1 Mean.2  600D6 Mean.1   FC.4  \
# 0                  0.142878  0.4270       1457.61       3021.26  0.480
# 1                  0.000682  0.0295         13.12        357.64  0.037
# 2                  0.068810  0.3000        231.00        634.69  0.360
#
#    P-value (600D6 vs 150CM)    FDR.5  600D6 Mean.2  150CM Mean.1   FC.5
# 0                  0.021191  0.13100       3021.26        652.72   4.63
# 1                  0.000014  0.00665        357.64         10.03  35.66
# 2                  0.007581  0.07400        634.69         88.33   7.19
#
# [3 rows x 44 columns]

# %%
master.columns
# Out:
# Index(['UniqueID', 'Symbol', '150.III', '150.II', '150.I', '600D1.III',
#        '600D1.II', '600D1.I', '600D6.III', '600D6.II', '600D6.I', 'CM150.III',
#        'CM150.II', 'CM150.I', 'P-value (150 vs 150 CM)', 'FDR', '150 Mean',
#        '150 CM Mean', 'FC', 'P-value (150 vs 600D1)', 'FDR.1', '150 Mean.1',
#        '600D1 Mean', 'FC.1', 'P-value (150 vs 600D6)', 'FDR.2', '150 Mean.2',
#        '600D6 Mean', 'FC.2', 'P-value (600D1 vs 150CM)', 'FDR.3',
#        '600D1 Mean.1', '150CM Mean', 'FC.3', 'P-value (600D1 vs 600D6)',
#        'FDR.4', '600D1 Mean.2', '600D6 Mean.1', 'FC.4',
#        'P-value (600D6 vs 150CM)', 'FDR.5', '600D6 Mean.2', '150CM Mean.1',
#        'FC.5'],
#       dtype='object')

# %%
master_600_150d6 = master[['UniqueID', 'Symbol',
                           'P-value (150 vs 600D6)', 'FDR.2', '150 Mean',
                           '600D6 Mean', 'FC.2']].copy()
master_600_150d6.head(3)
# Out:
#                UniqueID Symbol  P-value (150 vs 600D6)    FDR.2  150 Mean  \
# 0     TC1100006831.hg.1    ADM                0.000022  0.00318    118.38
# 1  HTA2-neg-47424102_st    NaN                0.000081  0.00602     15.76
# 2  HTA2-neg-47419722_st    NaN                0.000407  0.01430     36.88
#
#    600D6 Mean   FC.2
# 0     3021.26  0.039
# 1      357.64  0.044
# 2      634.69  0.058

# %%
master_600_150d6["FC2"] = master_600_150d6["600D6 Mean"]/master_600_150d6["150 Mean"]
master_600_150d6["FC2log"] = np.log2(master_600_150d6["FC2"])
master_600_150d6["logp"] = -np.log10(master_600_150d6["P-value (150 vs 600D6)"])
master_600_150d6.head(3)
# Out:
#                UniqueID Symbol  P-value (150 vs 600D6)    FDR.2  150 Mean  \
# 0     TC1100006831.hg.1    ADM                0.000022  0.00318    118.38
# 1  HTA2-neg-47424102_st    NaN                0.000081  0.00602     15.76
# 2  HTA2-neg-47419722_st    NaN                0.000407  0.01430     36.88
#
#    600D6 Mean   FC.2        FC2    FC2log      logp
# 0     3021.26  0.039  25.521710  4.673653  4.663540
# 1      357.64  0.044  22.692893  4.504169  4.089376
# 2      634.69  0.058  17.209599  4.105142  3.390512

# %%
master_600_150d6.columns
# Out:
# Index(['UniqueID', 'Symbol', 'P-value (150 vs 600D6)', 'FDR.2', '150 Mean',
#        '600D6 Mean', 'FC.2', 'FC2', 'FC2log', 'logp'],
#       dtype='object')

# %%
master_600_150d6_simple = master_600_150d6[['UniqueID', 'Symbol', 'P-value (150 vs 600D6)', 
                                                'FDR.2', 'FC2', 'FC2log', "logp"]].copy()
master_600_150d6_simple.head(3)
# Out:
#                UniqueID Symbol  P-value (150 vs 600D6)    FDR.2        FC2  \
# 0     TC1100006831.hg.1    ADM                0.000022  0.00318  25.521710
# 1  HTA2-neg-47424102_st    NaN                0.000081  0.00602  22.692893
# 2  HTA2-neg-47419722_st    NaN                0.000407  0.01430  17.209599
#
#      FC2log      logp
# 0  4.673653  4.663540
# 1  4.504169  4.089376
# 2  4.105142  3.390512

# %%
master_600_150d6_simple.shape
# Out:
# (24351, 7)

# %%
master_600_150d6_simple.dropna(axis = 0, how = "any", 
                               subset=["Symbol"], 
                               inplace = True)
master_600_150d6_simple.drop_duplicates(inplace=True, 
                                        ignore_index=True)
master_600_150d6_simple.shape
# Out:
# (21304, 7)

# %%
master_600_150d6_simple[master_600_150d6_simple.Symbol=="FMN1"]
# Out:
#                       UniqueID Symbol  P-value (150 vs 600D6)    FDR.2  \
# 3221   TSUnmapped00000592.hg.1   FMN1                0.083535  0.29000
# 5544   TSUnmapped00000704.hg.1   FMN1                0.517087  0.75100
# 10240  TSUnmapped00000640.hg.1   FMN1                0.932829  0.97200
# 11547  TSUnmapped00000754.hg.1   FMN1                0.962577  0.98500
# 14152        TC1500008955.hg.1   FMN1                0.540472  0.76600
# 16005  TSUnmapped00000626.hg.1   FMN1                0.279445  0.55300
# 16716        TC1500008960.hg.1   FMN1                0.154535  0.40600
# 16965        TC1500006791.hg.1   FMN1                0.147631  0.39600
# 18782  TSUnmapped00000772.hg.1   FMN1                0.098902  0.31900
# 19271  TSUnmapped00000529.hg.1   FMN1                0.025157  0.14900
# 19439  TSUnmapped00000654.hg.1   FMN1                0.013129  0.10500
# 20496  TSUnmapped00000703.hg.1   FMN1                0.019041  0.12900
# 20551  TSUnmapped00000606.hg.1   FMN1                0.031120  0.16700
# 21187  TSUnmapped00000713.hg.1   FMN1                0.000209  0.00997
# 21232  TSUnmapped00000559.hg.1   FMN1                0.000157  0.00845
#
#             FC2    FC2log      logp
# 3221   1.406288  0.491892  1.078132
# 5544   1.236792  0.306602  0.286436
# 10240  1.027778  0.039528  0.030198
# 11547  0.990117 -0.014329  0.016565
# 14152  0.888889 -0.169925  0.267227
# 16005  0.806478 -0.310294  0.553704
# 16716  0.767123 -0.382470  0.810973
# 16965  0.749733 -0.415552  0.830822
# 18782  0.627195 -0.673014  1.004795
# 19271  0.583228 -0.777868  1.599333
# 19439  0.566667 -0.819428  1.881775
# 20496  0.426382 -1.229781  1.720319
# 20551  0.417196 -1.261204  1.506955
# 21187  0.206723 -2.274227  3.679231
# 21232  0.182075 -2.457395  3.805208

# %% [markdown]
# # GO term sheet processing

# %%
folder = "data_for_volcano_plot/150CM_vs_150D6/"
files = pipe_util2.folder_file_num(folder)
files
# Out:
# data_for_volcano_plot/150CM_vs_150D6/ has 18 files
# ['data_for_volcano_plot/150CM_vs_150D6/GO_ACTIN_FILAMENT_BASED_PROCESS.xls',
#  'data_for_volcano_plot/150CM_vs_150D6/GO_ACTIN_FILAMENT_ORGANIZATION.xls',
#  'data_for_volcano_plot/150CM_vs_150D6/GO_BIOLOGICAL_ADHESION.xls',
#  'data_for_volcano_plot/150CM_vs_150D6/GO_CELL_CELL_ADHESION.xls',
#  'data_for_volcano_plot/150CM_vs_150D6/GO_CELL_CELL_JUNCTION_ORGANIZATION.xls',
#  'data_for_volcano_plot/150CM_vs_150D6/GO_CELL_JUNCTION_ASSEMBLY.xls',
#  'data_for_volcano_plot/150CM_vs_150D6/GO_CELL_JUNCTION_ORGANIZATION.xls',
#  'data_for_volcano_plot/150CM_vs_150D6/GO_CELL_PROJECTION_ASSEMBLY.xls',
#  'data_for_volcano_plot/150CM_vs_150D6/GO_EPITHELIAL_TO_MESENCHYMAL_TRANSITION.xls',
#  'data_for_volcano_plot/150CM_vs_150D6/GO_ESTABLISHMENT_OF_LOCALIZATION_IN_CELL.xls',
#  'data_for_volcano_plot/150CM_vs_150D6/GO_EXTRACELLULAR_STRUCTURE_ORGANIZATION.xls',
#  'data_for_volcano_plot/150CM_vs_150D6/GO_MEMBRANE_ORGANIZATION.xls',
#  'data_for_volcano_plot/150CM_vs_150D6/GO_NEGATIVE_REGULATION_OF_CELL_CELL_ADHESION.xls',
#  'data_for_volcano_plot/150CM_vs_150D6/GO_POSITIVE_REGULATION_OF_LOCOMOTION.xls',
#  'data_for_volcano_plot/150CM_vs_150D6/GO_REGULATION_OF_ACTIN_FILAMENT_BASED_PROCESS.xls',
#  'data_for_volcano_plot/150CM_vs_150D6/GO_REGULATION_OF_CELL_PROJECTION_ASSEMBLY.xls',
#  'data_for_volcano_plot/150CM_vs_150D6/GO_REGULATION_OF_CYTOSKELETON_ORGANIZATION.xls',
#  'data_for_volcano_plot/150CM_vs_150D6/GO_SUPRAMOLECULAR_FIBER_ORGANIZATION.xls']

# %%
name = os.path.basename(files[0])[3:-4]
name = name.replace("_", " ")
name = name.capitalize()
name
# Out:
# 'Actin filament based process'

# %%
def go_name(f):
    name = os.path.basename()[3:-4]
    name = name.replace("_", " ")
    name = name.capitalize()
    return name

# %%
df_merge = pd.merge(df, master_600_150d6, 
                    how = "left", 
                    left_on = "GENE SYMBOL", right_on = "Symbol")
df_merge
# Out:
#       PROBE GENE SYMBOL                                         GENE_TITLE  \
# 0   HSP90B1     HSP90B1  heat shock protein 90 beta family member 1 [So...
# 1   HSP90B1     HSP90B1  heat shock protein 90 beta family member 1 [So...
# 2    BAIAP2      BAIAP2  BAR/IMD domain containing adaptor protein 2 [S...
# 3    CORO1C      CORO1C      coronin 1C [Source:HGNC Symbol;Acc:HGNC:2254]
# 4      FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 5      FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 6      FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 7      FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 8      FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 9      FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 10     FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 11     FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 12     FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 13     FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 14     FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 15     FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 16     FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 17     FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 18     FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 19    TRPM4       TRPM4  transient receptor potential cation channel su...
# 20     BST2        BST2  bone marrow stromal cell antigen 2 [Source:HGN...
# 21    DAPK3       DAPK3  death associated protein kinase 3 [Source:HGNC...
# 22    SYNE2       SYNE2  spectrin repeat containing nuclear envelope pr...
# 23    SYNE2       SYNE2  spectrin repeat containing nuclear envelope pr...
# 24    AUTS2       AUTS2  activator of transcription and developmental r...
# 25    MYH10       MYH10  myosin heavy chain 10 [Source:HGNC Symbol;Acc:...
# 26   TGFBR1      TGFBR1  transforming growth factor beta receptor 1 [So...
# 27     TBCK        TBCK  TBC1 domain containing kinase [Source:HGNC Sym...
# 28     TBCK        TBCK  TBC1 domain containing kinase [Source:HGNC Sym...
# 29     RND3        RND3  Rho family GTPase 3 [Source:HGNC Symbol;Acc:HG...
# 30      DSP         DSP     desmoplakin [Source:HGNC Symbol;Acc:HGNC:3052]
# 31     ACTB        ACTB       actin beta [Source:HGNC Symbol;Acc:HGNC:132]
#
#     RANK IN GENE LIST  RANK METRIC SCORE    RUNNING ES CORE ENRICHMENT  \
# 0                   5               4.31  8.717621e-02             Yes
# 1                   5               4.31  8.717621e-02             Yes
# 2                  24               3.28  1.047394e-01             Yes
# 3                  25               3.28  1.841583e-01             Yes
# 4                  44               2.84  1.910678e-01             Yes
# 5                  44               2.84  1.910678e-01             Yes
# 6                  44               2.84  1.910678e-01             Yes
# 7                  44               2.84  1.910678e-01             Yes
# 8                  44               2.84  1.910678e-01             Yes
# 9                  44               2.84  1.910678e-01             Yes
# 10                 44               2.84  1.910678e-01             Yes
# 11                 44               2.84  1.910678e-01             Yes
# 12                 44               2.84  1.910678e-01             Yes
# 13                 44               2.84  1.910678e-01             Yes
# 14                 44               2.84  1.910678e-01             Yes
# 15                 44               2.84  1.910678e-01             Yes
# 16                 44               2.84  1.910678e-01             Yes
# 17                 44               2.84  1.910678e-01             Yes
# 18                 44               2.84  1.910678e-01             Yes
# 19                 81               2.44  1.264363e-01              No
# 20                 88               2.37  1.632028e-01              No
# 21                168               2.04 -5.888025e-02              No
# 22                198              -2.03 -1.093841e-01              No
# 23                198              -2.03 -1.093841e-01              No
# 24                203              -2.05 -7.349297e-02              No
# 25                226              -2.11 -9.800477e-02              No
# 26                235              -2.13 -7.392233e-02              No
# 27                253              -2.24 -7.810430e-02              No
# 28                253              -2.24 -7.810430e-02              No
# 29                285              -2.74 -1.182897e-01              No
# 30                291              -2.99 -6.307472e-02              No
# 31                305              -4.45 -8.894131e-08              No
#
#     Unnamed: 8                 UniqueID   Symbol  P-value (150 vs 600D6)  \
# 0          NaN        TC1200008667.hg.1  HSP90B1                0.181234
# 1          NaN        TC1200008666.hg.1  HSP90B1                0.066781
# 2          NaN        TC1700009150.hg.1   BAIAP2                0.247837
# 3          NaN        TC1200011846.hg.1   CORO1C                0.078265
# 4          NaN  TSUnmapped00000592.hg.1     FMN1                0.083535
# 5          NaN  TSUnmapped00000704.hg.1     FMN1                0.517087
# 6          NaN  TSUnmapped00000640.hg.1     FMN1                0.932829
# 7          NaN  TSUnmapped00000754.hg.1     FMN1                0.962577
# 8          NaN        TC1500008955.hg.1     FMN1                0.540472
# 9          NaN  TSUnmapped00000626.hg.1     FMN1                0.279445
# 10         NaN        TC1500008960.hg.1     FMN1                0.154535
# 11         NaN        TC1500006791.hg.1     FMN1                0.147631
# 12         NaN  TSUnmapped00000772.hg.1     FMN1                0.098902
# 13         NaN  TSUnmapped00000529.hg.1     FMN1                0.025157
# 14         NaN  TSUnmapped00000654.hg.1     FMN1                0.013129
# 15         NaN  TSUnmapped00000703.hg.1     FMN1                0.019041
# 16         NaN  TSUnmapped00000606.hg.1     FMN1                0.031120
# 17         NaN  TSUnmapped00000713.hg.1     FMN1                0.000209
# 18         NaN  TSUnmapped00000559.hg.1     FMN1                0.000157
# 19         NaN        TC1900008528.hg.1    TRPM4                0.009919
# 20         NaN        TC1900009970.hg.1     BST2                0.029483
# 21         NaN        TC1900009315.hg.1    DAPK3                0.003050
# 22         NaN        TC1400007431.hg.1    SYNE2                0.091576
# 23         NaN        TC1400007430.hg.1    SYNE2                0.066566
# 24         NaN        TC0700007905.hg.1    AUTS2                0.178189
# 25         NaN        TC1700009694.hg.1    MYH10                0.155561
# 26         NaN        TC0900008202.hg.1   TGFBR1                0.008905
# 27         NaN        TC0400011529.hg.1     TBCK                0.094439
# 28         NaN        TC0400011524.hg.1     TBCK                0.033859
# 29         NaN        TC0200014597.hg.1     RND3                0.007179
# 30         NaN        TC0600006869.hg.1      DSP                0.003139
# 31         NaN        TC0700010167.hg.1     ACTB                0.104138
#
#       FDR.2   150 Mean  600D6 Mean  FC.2       FC2    FC2log      logp
# 0   0.44200      33.17       53.88  0.62  1.624359  0.699871  0.741760
# 1   0.25700  243805.82   335844.22  0.73  1.377507  0.462060  1.175346
# 2   0.52000     806.96      594.03  1.36  0.736133 -0.441961  0.605834
# 3   0.27900     510.05      689.73  0.74  1.352279  0.435393  1.106431
# 4   0.29000       8.27       11.63  0.71  1.406288  0.491892  1.078132
# 5   0.75100      20.82       25.75  0.81  1.236792  0.306602  0.286436
# 6   0.97200     130.68      134.31  0.97  1.027778  0.039528  0.030198
# 7   0.98500      27.32       27.05  1.01  0.990117 -0.014329  0.016565
# 8   0.76600     272.52      242.24  1.13  0.888889 -0.169925  0.267227
# 9   0.55300      74.72       60.26  1.24  0.806478 -0.310294  0.553704
# 10  0.40600      26.28       20.16  1.30  0.767123 -0.382470  0.810973
# 11  0.39600      46.75       35.05  1.33  0.749733 -0.415552  0.830822
# 12  0.31900     101.93       63.93  1.59  0.627195 -0.673014  1.004795
# 13  0.14900     895.91      522.52  1.71  0.583228 -0.777868  1.599333
# 14  0.10500      34.80       19.72  1.76  0.566667 -0.819428  1.881775
# 15  0.12900      73.08       31.16  2.35  0.426382 -1.229781  1.720319
# 16  0.16700     121.31       50.61  2.40  0.417196 -1.261204  1.506955
# 17  0.00997     499.75      103.31  4.84  0.206723 -2.274227  3.679231
# 18  0.00845    3333.79      607.00  5.49  0.182075 -2.457395  3.805208
# 19  0.09080     137.74       74.77  1.84  0.542834 -0.881416  2.003515
# 20  0.16300     159.50       89.27  1.79  0.559687 -0.837309  1.530421
# 21  0.04620     566.02     1208.60  0.47  2.135260  1.094412  2.515729
# 22  0.30500      18.26       26.78  0.68  1.466594  0.552469  1.038219
# 23  0.25600     527.95      308.97  1.71  0.585226 -0.772935  1.176746
# 24  0.43900     945.93      755.88  1.25  0.799087 -0.323576  0.749119
# 25  0.40800    3423.27     2266.24  1.51  0.662010 -0.595074  0.808099
# 26  0.08560     114.70       56.75  2.02  0.494769 -1.015173  2.050366
# 27  0.31100      53.81       82.57  0.65  1.534473  0.617743  1.024850
# 28  0.17400     179.97       99.72  1.80  0.554092 -0.851802  1.470323
# 29  0.07500     321.51      744.65  0.43  2.316102  1.211699  2.143930
# 30  0.04700    3121.69     7964.22  0.39  2.551253  1.351206  2.503223
# 31  0.32800    1052.68      622.68  1.69  0.591519 -0.757504  0.982391

# %%
df_merge.sort_values(["Symbol", "FC2"], ascending=False, 
                     inplace=True)
df_merge
# Out:
#       PROBE GENE SYMBOL                                         GENE_TITLE  \
# 19    TRPM4       TRPM4  transient receptor potential cation channel su...
# 26   TGFBR1      TGFBR1  transforming growth factor beta receptor 1 [So...
# 27     TBCK        TBCK  TBC1 domain containing kinase [Source:HGNC Sym...
# 28     TBCK        TBCK  TBC1 domain containing kinase [Source:HGNC Sym...
# 22    SYNE2       SYNE2  spectrin repeat containing nuclear envelope pr...
# 23    SYNE2       SYNE2  spectrin repeat containing nuclear envelope pr...
# 29     RND3        RND3  Rho family GTPase 3 [Source:HGNC Symbol;Acc:HG...
# 25    MYH10       MYH10  myosin heavy chain 10 [Source:HGNC Symbol;Acc:...
# 0   HSP90B1     HSP90B1  heat shock protein 90 beta family member 1 [So...
# 1   HSP90B1     HSP90B1  heat shock protein 90 beta family member 1 [So...
# 4      FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 5      FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 6      FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 7      FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 8      FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 9      FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 10     FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 11     FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 12     FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 13     FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 14     FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 15     FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 16     FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 17     FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 18     FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 30      DSP         DSP     desmoplakin [Source:HGNC Symbol;Acc:HGNC:3052]
# 21    DAPK3       DAPK3  death associated protein kinase 3 [Source:HGNC...
# 3    CORO1C      CORO1C      coronin 1C [Source:HGNC Symbol;Acc:HGNC:2254]
# 20     BST2        BST2  bone marrow stromal cell antigen 2 [Source:HGN...
# 2    BAIAP2      BAIAP2  BAR/IMD domain containing adaptor protein 2 [S...
# 24    AUTS2       AUTS2  activator of transcription and developmental r...
# 31     ACTB        ACTB       actin beta [Source:HGNC Symbol;Acc:HGNC:132]
#
#     RANK IN GENE LIST  RANK METRIC SCORE    RUNNING ES CORE ENRICHMENT  \
# 19                 81               2.44  1.264363e-01              No
# 26                235              -2.13 -7.392233e-02              No
# 27                253              -2.24 -7.810430e-02              No
# 28                253              -2.24 -7.810430e-02              No
# 22                198              -2.03 -1.093841e-01              No
# 23                198              -2.03 -1.093841e-01              No
# 29                285              -2.74 -1.182897e-01              No
# 25                226              -2.11 -9.800477e-02              No
# 0                   5               4.31  8.717621e-02             Yes
# 1                   5               4.31  8.717621e-02             Yes
# 4                  44               2.84  1.910678e-01             Yes
# 5                  44               2.84  1.910678e-01             Yes
# 6                  44               2.84  1.910678e-01             Yes
# 7                  44               2.84  1.910678e-01             Yes
# 8                  44               2.84  1.910678e-01             Yes
# 9                  44               2.84  1.910678e-01             Yes
# 10                 44               2.84  1.910678e-01             Yes
# 11                 44               2.84  1.910678e-01             Yes
# 12                 44               2.84  1.910678e-01             Yes
# 13                 44               2.84  1.910678e-01             Yes
# 14                 44               2.84  1.910678e-01             Yes
# 15                 44               2.84  1.910678e-01             Yes
# 16                 44               2.84  1.910678e-01             Yes
# 17                 44               2.84  1.910678e-01             Yes
# 18                 44               2.84  1.910678e-01             Yes
# 30                291              -2.99 -6.307472e-02              No
# 21                168               2.04 -5.888025e-02              No
# 3                  25               3.28  1.841583e-01             Yes
# 20                 88               2.37  1.632028e-01              No
# 2                  24               3.28  1.047394e-01             Yes
# 24                203              -2.05 -7.349297e-02              No
# 31                305              -4.45 -8.894131e-08              No
#
#     Unnamed: 8                 UniqueID   Symbol  P-value (150 vs 600D6)  \
# 19         NaN        TC1900008528.hg.1    TRPM4                0.009919
# 26         NaN        TC0900008202.hg.1   TGFBR1                0.008905
# 27         NaN        TC0400011529.hg.1     TBCK                0.094439
# 28         NaN        TC0400011524.hg.1     TBCK                0.033859
# 22         NaN        TC1400007431.hg.1    SYNE2                0.091576
# 23         NaN        TC1400007430.hg.1    SYNE2                0.066566
# 29         NaN        TC0200014597.hg.1     RND3                0.007179
# 25         NaN        TC1700009694.hg.1    MYH10                0.155561
# 0          NaN        TC1200008667.hg.1  HSP90B1                0.181234
# 1          NaN        TC1200008666.hg.1  HSP90B1                0.066781
# 4          NaN  TSUnmapped00000592.hg.1     FMN1                0.083535
# 5          NaN  TSUnmapped00000704.hg.1     FMN1                0.517087
# 6          NaN  TSUnmapped00000640.hg.1     FMN1                0.932829
# 7          NaN  TSUnmapped00000754.hg.1     FMN1                0.962577
# 8          NaN        TC1500008955.hg.1     FMN1                0.540472
# 9          NaN  TSUnmapped00000626.hg.1     FMN1                0.279445
# 10         NaN        TC1500008960.hg.1     FMN1                0.154535
# 11         NaN        TC1500006791.hg.1     FMN1                0.147631
# 12         NaN  TSUnmapped00000772.hg.1     FMN1                0.098902
# 13         NaN  TSUnmapped00000529.hg.1     FMN1                0.025157
# 14         NaN  TSUnmapped00000654.hg.1     FMN1                0.013129
# 15         NaN  TSUnmapped00000703.hg.1     FMN1                0.019041
# 16         NaN  TSUnmapped00000606.hg.1     FMN1                0.031120
# 17         NaN  TSUnmapped00000713.hg.1     FMN1                0.000209
# 18         NaN  TSUnmapped00000559.hg.1     FMN1                0.000157
# 30         NaN        TC0600006869.hg.1      DSP                0.003139
# 21         NaN        TC1900009315.hg.1    DAPK3                0.003050
# 3          NaN        TC1200011846.hg.1   CORO1C                0.078265
# 20         NaN        TC1900009970.hg.1     BST2                0.029483
# 2          NaN        TC1700009150.hg.1   BAIAP2                0.247837
# 24         NaN        TC0700007905.hg.1    AUTS2                0.178189
# 31         NaN        TC0700010167.hg.1     ACTB                0.104138
#
#       FDR.2   150 Mean  600D6 Mean  FC.2       FC2    FC2log      logp
# 19  0.09080     137.74       74.77  1.84  0.542834 -0.881416  2.003515
# 26  0.08560     114.70       56.75  2.02  0.494769 -1.015173  2.050366
# 27  0.31100      53.81       82.57  0.65  1.534473  0.617743  1.024850
# 28  0.17400     179.97       99.72  1.80  0.554092 -0.851802  1.470323
# 22  0.30500      18.26       26.78  0.68  1.466594  0.552469  1.038219
# 23  0.25600     527.95      308.97  1.71  0.585226 -0.772935  1.176746
# 29  0.07500     321.51      744.65  0.43  2.316102  1.211699  2.143930
# 25  0.40800    3423.27     2266.24  1.51  0.662010 -0.595074  0.808099
# 0   0.44200      33.17       53.88  0.62  1.624359  0.699871  0.741760
# 1   0.25700  243805.82   335844.22  0.73  1.377507  0.462060  1.175346
# 4   0.29000       8.27       11.63  0.71  1.406288  0.491892  1.078132
# 5   0.75100      20.82       25.75  0.81  1.236792  0.306602  0.286436
# 6   0.97200     130.68      134.31  0.97  1.027778  0.039528  0.030198
# 7   0.98500      27.32       27.05  1.01  0.990117 -0.014329  0.016565
# 8   0.76600     272.52      242.24  1.13  0.888889 -0.169925  0.267227
# 9   0.55300      74.72       60.26  1.24  0.806478 -0.310294  0.553704
# 10  0.40600      26.28       20.16  1.30  0.767123 -0.382470  0.810973
# 11  0.39600      46.75       35.05  1.33  0.749733 -0.415552  0.830822
# 12  0.31900     101.93       63.93  1.59  0.627195 -0.673014  1.004795
# 13  0.14900     895.91      522.52  1.71  0.583228 -0.777868  1.599333
# 14  0.10500      34.80       19.72  1.76  0.566667 -0.819428  1.881775
# 15  0.12900      73.08       31.16  2.35  0.426382 -1.229781  1.720319
# 16  0.16700     121.31       50.61  2.40  0.417196 -1.261204  1.506955
# 17  0.00997     499.75      103.31  4.84  0.206723 -2.274227  3.679231
# 18  0.00845    3333.79      607.00  5.49  0.182075 -2.457395  3.805208
# 30  0.04700    3121.69     7964.22  0.39  2.551253  1.351206  2.503223
# 21  0.04620     566.02     1208.60  0.47  2.135260  1.094412  2.515729
# 3   0.27900     510.05      689.73  0.74  1.352279  0.435393  1.106431
# 20  0.16300     159.50       89.27  1.79  0.559687 -0.837309  1.530421
# 2   0.52000     806.96      594.03  1.36  0.736133 -0.441961  0.605834
# 24  0.43900     945.93      755.88  1.25  0.799087 -0.323576  0.749119
# 31  0.32800    1052.68      622.68  1.69  0.591519 -0.757504  0.982391

# %%
df_merge_simple = df_merge.drop_duplicates(subset="Symbol").copy()
df_merge_simple
# Out:
#       PROBE GENE SYMBOL                                         GENE_TITLE  \
# 19    TRPM4       TRPM4  transient receptor potential cation channel su...
# 26   TGFBR1      TGFBR1  transforming growth factor beta receptor 1 [So...
# 27     TBCK        TBCK  TBC1 domain containing kinase [Source:HGNC Sym...
# 22    SYNE2       SYNE2  spectrin repeat containing nuclear envelope pr...
# 29     RND3        RND3  Rho family GTPase 3 [Source:HGNC Symbol;Acc:HG...
# 25    MYH10       MYH10  myosin heavy chain 10 [Source:HGNC Symbol;Acc:...
# 0   HSP90B1     HSP90B1  heat shock protein 90 beta family member 1 [So...
# 4      FMN1        FMN1        formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]
# 30      DSP         DSP     desmoplakin [Source:HGNC Symbol;Acc:HGNC:3052]
# 21    DAPK3       DAPK3  death associated protein kinase 3 [Source:HGNC...
# 3    CORO1C      CORO1C      coronin 1C [Source:HGNC Symbol;Acc:HGNC:2254]
# 20     BST2        BST2  bone marrow stromal cell antigen 2 [Source:HGN...
# 2    BAIAP2      BAIAP2  BAR/IMD domain containing adaptor protein 2 [S...
# 24    AUTS2       AUTS2  activator of transcription and developmental r...
# 31     ACTB        ACTB       actin beta [Source:HGNC Symbol;Acc:HGNC:132]
#
#     RANK IN GENE LIST  RANK METRIC SCORE    RUNNING ES CORE ENRICHMENT  \
# 19                 81               2.44  1.264363e-01              No
# 26                235              -2.13 -7.392233e-02              No
# 27                253              -2.24 -7.810430e-02              No
# 22                198              -2.03 -1.093841e-01              No
# 29                285              -2.74 -1.182897e-01              No
# 25                226              -2.11 -9.800477e-02              No
# 0                   5               4.31  8.717621e-02             Yes
# 4                  44               2.84  1.910678e-01             Yes
# 30                291              -2.99 -6.307472e-02              No
# 21                168               2.04 -5.888025e-02              No
# 3                  25               3.28  1.841583e-01             Yes
# 20                 88               2.37  1.632028e-01              No
# 2                  24               3.28  1.047394e-01             Yes
# 24                203              -2.05 -7.349297e-02              No
# 31                305              -4.45 -8.894131e-08              No
#
#     Unnamed: 8                 UniqueID   Symbol  P-value (150 vs 600D6)  \
# 19         NaN        TC1900008528.hg.1    TRPM4                0.009919
# 26         NaN        TC0900008202.hg.1   TGFBR1                0.008905
# 27         NaN        TC0400011529.hg.1     TBCK                0.094439
# 22         NaN        TC1400007431.hg.1    SYNE2                0.091576
# 29         NaN        TC0200014597.hg.1     RND3                0.007179
# 25         NaN        TC1700009694.hg.1    MYH10                0.155561
# 0          NaN        TC1200008667.hg.1  HSP90B1                0.181234
# 4          NaN  TSUnmapped00000592.hg.1     FMN1                0.083535
# 30         NaN        TC0600006869.hg.1      DSP                0.003139
# 21         NaN        TC1900009315.hg.1    DAPK3                0.003050
# 3          NaN        TC1200011846.hg.1   CORO1C                0.078265
# 20         NaN        TC1900009970.hg.1     BST2                0.029483
# 2          NaN        TC1700009150.hg.1   BAIAP2                0.247837
# 24         NaN        TC0700007905.hg.1    AUTS2                0.178189
# 31         NaN        TC0700010167.hg.1     ACTB                0.104138
#
#      FDR.2  150 Mean  600D6 Mean  FC.2       FC2    FC2log      logp
# 19  0.0908    137.74       74.77  1.84  0.542834 -0.881416  2.003515
# 26  0.0856    114.70       56.75  2.02  0.494769 -1.015173  2.050366
# 27  0.3110     53.81       82.57  0.65  1.534473  0.617743  1.024850
# 22  0.3050     18.26       26.78  0.68  1.466594  0.552469  1.038219
# 29  0.0750    321.51      744.65  0.43  2.316102  1.211699  2.143930
# 25  0.4080   3423.27     2266.24  1.51  0.662010 -0.595074  0.808099
# 0   0.4420     33.17       53.88  0.62  1.624359  0.699871  0.741760
# 4   0.2900      8.27       11.63  0.71  1.406288  0.491892  1.078132
# 30  0.0470   3121.69     7964.22  0.39  2.551253  1.351206  2.503223
# 21  0.0462    566.02     1208.60  0.47  2.135260  1.094412  2.515729
# 3   0.2790    510.05      689.73  0.74  1.352279  0.435393  1.106431
# 20  0.1630    159.50       89.27  1.79  0.559687 -0.837309  1.530421
# 2   0.5200    806.96      594.03  1.36  0.736133 -0.441961  0.605834
# 24  0.4390    945.93      755.88  1.25  0.799087 -0.323576  0.749119
# 31  0.3280   1052.68      622.68  1.69  0.591519 -0.757504  0.982391

# %%
df_merge_simple.columns
# Out:
# Index(['PROBE', 'GENE SYMBOL', 'GENE_TITLE', 'RANK IN GENE LIST',
#        'RANK METRIC SCORE', 'RUNNING ES', 'CORE ENRICHMENT', 'Unnamed: 8',
#        'UniqueID', 'Symbol', 'P-value (150 vs 600D6)', 'FDR.2', '150 Mean',
#        '600D6 Mean', 'FC.2', 'FC2', 'FC2log', 'logp'],
#       dtype='object')

# %%
df_merge_simple = df_merge_simple[['UniqueID', 'Symbol', 'GENE_TITLE', 
                                   'P-value (150 vs 600D6)', 
                                   'FDR.2', 'FC2','FC2log']].copy()
df_merge_simple
# Out:
#                    UniqueID   Symbol  \
# 19        TC1900008528.hg.1    TRPM4
# 26        TC0900008202.hg.1   TGFBR1
# 27        TC0400011529.hg.1     TBCK
# 22        TC1400007431.hg.1    SYNE2
# 29        TC0200014597.hg.1     RND3
# 25        TC1700009694.hg.1    MYH10
# 0         TC1200008667.hg.1  HSP90B1
# 4   TSUnmapped00000592.hg.1     FMN1
# 30        TC0600006869.hg.1      DSP
# 21        TC1900009315.hg.1    DAPK3
# 3         TC1200011846.hg.1   CORO1C
# 20        TC1900009970.hg.1     BST2
# 2         TC1700009150.hg.1   BAIAP2
# 24        TC0700007905.hg.1    AUTS2
# 31        TC0700010167.hg.1     ACTB
#
#                                            GENE_TITLE  P-value (150 vs 600D6)  \
# 19  transient receptor potential cation channel su...                0.009919
# 26  transforming growth factor beta receptor 1 [So...                0.008905
# 27  TBC1 domain containing kinase [Source:HGNC Sym...                0.094439
# 22  spectrin repeat containing nuclear envelope pr...                0.091576
# 29  Rho family GTPase 3 [Source:HGNC Symbol;Acc:HG...                0.007179
# 25  myosin heavy chain 10 [Source:HGNC Symbol;Acc:...                0.155561
# 0   heat shock protein 90 beta family member 1 [So...                0.181234
# 4         formin 1 [Source:HGNC Symbol;Acc:HGNC:3768]                0.083535
# 30     desmoplakin [Source:HGNC Symbol;Acc:HGNC:3052]                0.003139
# 21  death associated protein kinase 3 [Source:HGNC...                0.003050
# 3       coronin 1C [Source:HGNC Symbol;Acc:HGNC:2254]                0.078265
# 20  bone marrow stromal cell antigen 2 [Source:HGN...                0.029483
# 2   BAR/IMD domain containing adaptor protein 2 [S...                0.247837
# 24  activator of transcription and developmental r...                0.178189
# 31       actin beta [Source:HGNC Symbol;Acc:HGNC:132]                0.104138
#
#      FDR.2       FC2    FC2log
# 19  0.0908  0.542834 -0.881416
# 26  0.0856  0.494769 -1.015173
# 27  0.3110  1.534473  0.617743
# 22  0.3050  1.466594  0.552469
# 29  0.0750  2.316102  1.211699
# 25  0.4080  0.662010 -0.595074
# 0   0.4420  1.624359  0.699871
# 4   0.2900  1.406288  0.491892
# 30  0.0470  2.551253  1.351206
# 21  0.0462  2.135260  1.094412
# 3   0.2790  1.352279  0.435393
# 20  0.1630  0.559687 -0.837309
# 2   0.5200  0.736133 -0.441961
# 24  0.4390  0.799087 -0.323576
# 31  0.3280  0.591519 -0.757504

# %%
def df_merge(master, file):
    
    # Go process name
    name = os.path.basename(file)[3:-4]
    name = name.replace("_", " ")
    name = name.capitalize()
    
    df = pd.read_csv(file, sep = "\t", header = 0, index_col=0)
    # merge dataframe
    df_merge = pd.merge(df, master, 
                        how = "left", 
                        left_on = "GENE SYMBOL", right_on = "Symbol")
    # remove duplicated genes
    df_merge.sort_values(["Symbol", "FC2log"], ascending=False, 
                         inplace=True)
    df_merge_simple = df_merge.drop_duplicates(subset="Symbol").copy()
    # selecting few columns
    df_merge_simple = df_merge_simple[['UniqueID', 'Symbol', 
                                       'GENE_TITLE', 
                                       'P-value (150 vs 600D6)', 
                                       'FDR.2', 'FC2','FC2log', 
                                       'logp']].copy()
    # go term name
#     df_merge_simple["go"] = name
    # reset index
    df_merge_simple.reset_index(drop=True, inplace=True)
    return df_merge_simple

# %%
df_list = []
for f in files:
    df = df_merge(master_600_150d6_simple, f)
    df_list.append(df)
df_all = pd.concat(df_list)
df_all.drop_duplicates(inplace=True)
df_all.sort_values(["FC2"], ascending=False, inplace=True)
df_all.reset_index(drop=True, inplace=True)
df_all.shape
# Out:
# (248, 9)

# %%
plt.figure(figsize=(4,6))
# plt.scatter(df_all.FC2log, df_all.logp, s=12)

p_thre = -np.log10(0.05)

df_all_up = df_all[(df_all.FC2log>1) & (df_all.logp>p_thre)].copy()
up_num = df_all_up.shape[0]
plt.scatter(df_all_up.FC2log, df_all_up.logp, 
            s=12, c="red", label = "Up regulated: %s"%(up_num))
df_all_down = df_all[(df_all.FC2log<-1) & (df_all.logp>p_thre)].copy()
down_num = df_all_down.shape[0]
plt.scatter(df_all_down.FC2log, df_all_down.logp, 
            s=12, c="blue", label = "Down regulated: %s"%(down_num))
df_all_non = df_all[(df_all.FC2log.abs()<=1) | (df_all.logp<=p_thre)].copy()
non_num = df_all_non.shape[0]
plt.scatter(df_all_non.FC2log, df_all_non.logp, s=12, c="gray")


plt.axvline(x = -1,c="k", linestyle="-.")
plt.axvline(x = 1, c="k", linestyle="-.")
plt.axhline(y = p_thre, c="k", linestyle="-.")

# label top genes
df_all_top = pd.concat([df_all_up, df_all_down])
df_all_top["FC2logabs"] = df_all_top["FC2log"].abs()
df_all_top.sort_values(["FC2log"], ascending=False, inplace = True)
df_all_top_save = df_all_top.copy()
df_all_top_save.to_csv("Volcano_data_600.csv") # save to file
df_all_top.sort_values(["FC2logabs"], ascending=False, inplace = True)
print(df_all_top.shape[0])
df_all_top = df_all_top.loc[:15, :]
for i in range(df_all_top.shape[0]):
    plt.text(df_all_top.FC2log.values[i]+0.05, df_all_top.logp.values[i]+0.05, 
            str(df_all_top.Symbol.values[i]), 
            color='k', fontsize=7)
    
df_all_non.sort_values(["FC2log"], ascending=False, inplace = True)
df_all_non.to_csv("Volcano_non_data.csv")

plt.legend(title="Differential expressed genes", 
           bbox_to_anchor=(1, 1.18),
           frameon=True)
    
# plt.xlim((-3.5, 3.5))
plt.xlabel(r"$log_2(fold\ change)$", fontsize=12)
plt.ylabel(r"$-log_{10}(pval)$", fontsize=12)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(True)
plt.gca().spines['left'].set_visible(True)

plt.tight_layout()
plt.savefig("Volcano_600.pdf")
# Out:
# 95
